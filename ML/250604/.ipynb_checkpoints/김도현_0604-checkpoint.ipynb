# %% [markdown]
# # 문제 1

# %%
import pandas as pd

df = pd.read_csv('../AI데이터/titanic/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df2 = df.copy()
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Passengerid, Name, Ticket, Cabin 컬럼 삭제

# %%
df2 = df2.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis = 1)
df2
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# #### Nan 데이터는 삭제

# %%
df2 = df2.dropna()
df2
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 885         0       3  female  39.0      0      5  29.1250        Q
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [712 rows x 8 columns]

# %% [markdown]
# #### Sex, Emabrked는 레이블 인코딩

# %%
from sklearn.preprocessing import LabelEncoder

# Sex, Embarked 레이블 인코딩
df2['Sex'] = LabelEncoder().fit_transform(df2['Sex'])
df2['Embarked'] = LabelEncoder().fit_transform(df2['Embarked'])
df2
# Out:
# C:\Users\KDT4\AppData\Local\Temp\ipykernel_13552\1237253420.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Sex'] = LabelEncoder().fit_transform(df2['Sex'])
# C:\Users\KDT4\AppData\Local\Temp\ipykernel_13552\1237253420.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Embarked'] = LabelEncoder().fit_transform(df2['Embarked'])
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.0      1      0   7.2500         2
# ...

# %% [markdown]
# #### Age, Fare는 MinMaxScaler로 전처리

# %%
from sklearn.preprocessing import MinMaxScaler

cols_to_scale = ['Age', 'Fare']

scaler = MinMaxScaler()

df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])
df2
# Out:
# C:\Users\KDT4\AppData\Local\Temp\ipykernel_13552\1388184224.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])
#      Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0           0       3    1  0.271174      1      0  0.014151         2
# 1           1       1    0  0.472229      1      0  0.139136         0
# 2           1       3    0  0.321438      0      0  0.015469         2
# 3           1       1    0  0.434531      1      0  0.103644         2
# 4           0       3    1  0.434531      0      0  0.015713         2
# ..        ...     ...  ...       ...    ...    ...       ...       ...
# ...

# %% [markdown]
# #### Survived 마지막 컬럼으로 이동

# %%
survived_col = df2.pop('Survived')
df2 = df2.assign(Survived=survived_col)
df2
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked  Survived
# 0         3    1  0.271174      1      0  0.014151         2         0
# 1         1    0  0.472229      1      0  0.139136         0         1
# 2         3    0  0.321438      0      0  0.015469         2         1
# 3         1    0  0.434531      1      0  0.103644         2         1
# 4         3    1  0.434531      0      0  0.015713         2         0
# ..      ...  ...       ...    ...    ...       ...       ...       ...
# 885       3    0  0.484795      0      5  0.056848         1         0
# 886       2    1  0.334004      0      0  0.025374         2         0
# 887       1    0  0.233476      0      0  0.058556         2         1
# 889       1    1  0.321438      0      0  0.058556         0         1
# 890       3    1  0.396833      0      0  0.015127         1         0
#
# [712 rows x 8 columns]

# %% [markdown]
# #### VIF 10이상 제거

# %%
df2.iloc[:, :-1].columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'], dtype='object')

# %%
import statsmodels.formula.api as smf

formula = 'Survived~' + '+'.join(df2.iloc[:, :-1].columns)
formula
# Out:
# 'Survived~Pclass+Sex+Age+SibSp+Parch+Fare+Embarked'

# %%
# OLS(Ordinary Least Squares) 모델 OLS(Ordinary Least Squares) 모델
model_titanic = smf.ols(formula = formula, data = df2).fit()
model_titanic.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.394
# Method:                 Least Squares   F-statistic:                     67.16
# Date:                Wed, 04 Jun 2025   Prob (F-statistic):           4.63e-74
# Time:                        16:26:11   Log-Likelihood:                -321.43
# No. Observations:                 712   AIC:                             658.9
# Df Residuals:                     704   BIC:                             695.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3999      0.081     17.241      0.000       1.240       1.559
# ...

# %%
from patsy import dmatrices

y, X = dmatrices(formula, df2, return_type = 'dataframe')

# %%
y # 종속변수
# Out:
#      Survived
# 0         0.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         0.0
# ..        ...
# 885       0.0
# 886       0.0
# 887       1.0
# 889       1.0
# 890       0.0
#
# [712 rows x 1 columns]

# %%
X # 독립변수
# Out:
#      Intercept  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0          1.0     3.0  1.0  0.271174    1.0    0.0  0.014151       2.0
# 1          1.0     1.0  0.0  0.472229    1.0    0.0  0.139136       0.0
# 2          1.0     3.0  0.0  0.321438    0.0    0.0  0.015469       2.0
# 3          1.0     1.0  0.0  0.434531    1.0    0.0  0.103644       2.0
# 4          1.0     3.0  1.0  0.434531    0.0    0.0  0.015713       2.0
# ..         ...     ...  ...       ...    ...    ...       ...       ...
# 885        1.0     3.0  0.0  0.484795    0.0    5.0  0.056848       1.0
# 886        1.0     2.0  1.0  0.334004    0.0    0.0  0.025374       2.0
# 887        1.0     1.0  0.0  0.233476    0.0    0.0  0.058556       2.0
# 889        1.0     1.0  1.0  0.321438    0.0    0.0  0.058556       0.0
# 890        1.0     3.0  1.0  0.396833    0.0    0.0  0.015127       1.0
#
# [712 rows x 8 columns]

# %%
import pandas as pd

vif = pd.DataFrame()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif['VIF Factor'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['features'] = X.columns
vif
# Out:
#    VIF Factor   features
# 0   32.134512  Intercept
# 1    1.749120     Pclass
# 2    1.119651        Sex
# 3    1.310796        Age
# 4    1.276469      SibSp
# 5    1.288619      Parch
# 6    1.641348       Fare
# 7    1.114880   Embarked

# %%
def get_vif(formula, df):
    from patsy import dmatrices
    
    y, X = dmatrices(formula, df, return_type = 'dataframe')
    import pandas as pd
    
    vif = pd.DataFrame()
    
    from statsmodels.stats.outliers_influence import variance_inflation_factor

    vif['VIF Factor'] = [variance_inflation_factor(X.values, i) 
                         for i in range(X.shape[1])]
    vif['features'] = X.columns
    
    return vif

# %%
formula = 'Survived~' + '+'.join(df2.iloc[:, :-1].columns) + '-1'
print(formula)
get_vif(formula, df2)
# Out:
# Survived~Pclass+Sex+Age+SibSp+Parch+Fare+Embarked-1
#    VIF Factor  features
# 0    5.974701    Pclass
# 1    3.034949       Sex
# 2    4.104924       Age
# 3    1.639080     SibSp
# 4    1.618650     Parch
# 5    1.655179      Fare
# 6    5.278139  Embarked

# %%
# OLS(Ordinary Least Squares) 모델 OLS(Ordinary Least Squares) 모델
model_titanic = smf.ols(formula = formula, data = df2).fit()
model_titanic.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared (uncentered):                   0.492
# Model:                            OLS   Adj. R-squared (uncentered):              0.487
# Method:                 Least Squares   F-statistic:                              97.61
# Date:                Wed, 04 Jun 2025   Prob (F-statistic):                    2.24e-99
# Time:                        16:26:15   Log-Likelihood:                         -446.83
# No. Observations:                 712   AIC:                                      907.7
# Df Residuals:                     705   BIC:                                      939.6
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# # 문제 2

# %%
import pandas as pd
df = pd.read_csv('../AI데이터/newbie.csv')
df
# Out:
#            who  Newbie   Age  Gender Household Income Sexual Preference  \
# 0      id74364       0  54.0    Male           $50-74          Gay male
# 1      id84505       0  39.0  Female        Over $100      Heterosexual
# 2      id84509       1  49.0  Female           $40-49      Heterosexual
# 3      id87028       1  22.0  Female           $40-49      Heterosexual
# 4      id76087       0  20.0    Male           $30-39          Bisexual
# ...        ...     ...   ...     ...              ...               ...
# 19578  id83400       0  22.0    Male        Over $100      Heterosexual
# 19579  id72216       0  19.0    Male              NaN      Heterosexual
# 19580   id8654       0  49.0  Female           $50-74      Heterosexual
# 19581  id84503       1  42.0  Female           $50-74      Heterosexual
# 19582  id87674       0  24.0  Female           $50-74       Transgender
#
#           Country Education Attainment Major Occupation Marital Status  \
# ...

# %%
df2 = df.copy()
df2
# Out:
#            who  Newbie   Age  Gender Household Income Sexual Preference  \
# 0      id74364       0  54.0    Male           $50-74          Gay male
# 1      id84505       0  39.0  Female        Over $100      Heterosexual
# 2      id84509       1  49.0  Female           $40-49      Heterosexual
# 3      id87028       1  22.0  Female           $40-49      Heterosexual
# 4      id76087       0  20.0    Male           $30-39          Bisexual
# ...        ...     ...   ...     ...              ...               ...
# 19578  id83400       0  22.0    Male        Over $100      Heterosexual
# 19579  id72216       0  19.0    Male              NaN      Heterosexual
# 19580   id8654       0  49.0  Female           $50-74      Heterosexual
# 19581  id84503       1  42.0  Female           $50-74      Heterosexual
# 19582  id87674       0  24.0  Female           $50-74       Transgender
#
#           Country Education Attainment Major Occupation Marital Status  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19583 entries, 0 to 19582
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   who                   19583 non-null  object
#  1   Newbie                19583 non-null  int64
#  2   Age                   19022 non-null  float64
#  3   Gender                19583 non-null  object
#  4   Household Income      16398 non-null  object
#  5   Sexual Preference     18291 non-null  object
#  6   Country               19583 non-null  object
#  7   Education Attainment  19583 non-null  object
#  8   Major Occupation      19583 non-null  object
#  9   Marital Status        19240 non-null  object
#  10  Years on Internet     19583 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 1.6+ MB

# %%
newbie_col = df2.pop('Newbie')
df2 = df2.assign(Newbie=newbie_col)
df2
# Out:
#            who   Age  Gender Household Income Sexual Preference     Country  \
# 0      id74364  54.0    Male           $50-74          Gay male     Ontario
# 1      id84505  39.0  Female        Over $100      Heterosexual      Sweden
# 2      id84509  49.0  Female           $40-49      Heterosexual  Washington
# 3      id87028  22.0  Female           $40-49      Heterosexual     Florida
# 4      id76087  20.0    Male           $30-39          Bisexual  New Jersey
# ...        ...   ...     ...              ...               ...         ...
# 19578  id83400  22.0    Male        Over $100      Heterosexual       Texas
# 19579  id72216  19.0    Male              NaN      Heterosexual  New Jersey
# 19580   id8654  49.0  Female           $50-74      Heterosexual    Missouri
# 19581  id84503  42.0  Female           $50-74      Heterosexual    Kentucky
# 19582  id87674  24.0  Female           $50-74       Transgender  California
#
# ...

# %% [markdown]
# ### Age 결측값 처리

# %%
from sklearn.impute import SimpleImputer
import numpy as np

imp_mean = SimpleImputer(missing_values = np.nan, strategy = 'mean')
df2[['Age']] = imp_mean.fit_transform(df2[['Age']])

df2.Age.isnull().sum()
# Out:
# np.int64(0)

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
import numpy as np

imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# Household Income
df2['Household Income'] = imp.fit_transform(df2[['Household Income']]).ravel()
df2['Household Income'] = LabelEncoder().fit_transform(df2['Household Income'])

# Sexual Preference
df2['Sexual Preference'] = imp.fit_transform(df2[['Sexual Preference']]).ravel()
df2['Sexual Preference'] = LabelEncoder().fit_transform(df2['Sexual Preference'])

# Marital Status
df2['Marital Status'] = imp.fit_transform(df2[['Marital Status']]).ravel()
df2['Marital Status'] = LabelEncoder().fit_transform(df2['Marital Status'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19583 entries, 0 to 19582
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   who                   19583 non-null  object
#  1   Age                   19583 non-null  float64
#  2   Gender                19583 non-null  object
#  3   Household Income      19583 non-null  int64
#  4   Sexual Preference     19583 non-null  int64
#  5   Country               19583 non-null  object
#  6   Education Attainment  19583 non-null  object
#  7   Major Occupation      19583 non-null  object
#  8   Marital Status        19583 non-null  int64
#  9   Years on Internet     19583 non-null  object
#  10  Newbie                19583 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.6+ MB

# %% [markdown]
# #### 독립 변수 제거 : 'who', 'Country', 'Years on Internet‘

# %%
df2 = df2.drop(['who', 'Country', 'Years on Internet'], axis = 1)
df2
# Out:
#         Age  Gender  Household Income  Sexual Preference Education Attainment  \
# 0      54.0    Male                 4                  1         Some College
# 1      39.0  Female                 6                  2         Professional
# 2      49.0  Female                 3                  2         Some College
# 3      22.0  Female                 3                  2         Some College
# 4      20.0    Male                 2                  0         Some College
# ...     ...     ...               ...                ...                  ...
# 19578  22.0    Male                 6                  2         Some College
# 19579  19.0    Male                 4                  2         Some College
# 19580  49.0  Female                 4                  2             Doctoral
# 19581  42.0  Female                 4                  2         Some College
# 19582  24.0  Female                 4                  4              College
#
# ...

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def loss_func(x, t):
    delta = 1e-7 # Log 무한대 발산 방
    z = np.dot(x, W) + b
    y = sigmoid(z)
    
    return -np.sum(t * np.log(y + delta) + (1 - t) * np.log((1 - y) + delta)) # cross-entropy

# %%
def predict(test_data):
    z = np.dot(test_data, W) + b
    y = sigmoid(z)
    if y >= 0.5:
        result = 1 # Pass
    else:
        result = 0 # Fail

    return y, result

# %%
def numerical_derivative(f, x):
    delta_x = 1e-4
    grad = np.zeros_like(x)
    it = np.nditer(x, flags = ['multi_index'], op_flags = ['readwrite'])
    while not it.finished:
        idx = it.multi_index
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + delta_x
        fx1 = f(x) # f(x + delta_x)

        x[idx] = float(tmp_val) - delta_x
        fx2 = f(x)
        grad[idx] = (fx1 - fx2) / (2 * delta_x)
        x[idx] = tmp_val
        it.iternext()

    return grad

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver="liblinear")

# %%
from sklearn.preprocessing import LabelEncoder

# 범주형 컬럼 전처리
for col in df2.columns:
    if df2[col].dtype == 'object':
        df2[col] = LabelEncoder().fit_transform(df2[col].astype(str))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df2.iloc[:, :-1],
                                                    df2.loc[:, "Newbie"], random_state = 42)
model.fit(X_train, y_train)
score = model.score(X_test, y_test)
print(f'전체 데이터로 예측한 결과 : {score}')
# Out:
# 전체 데이터로 예측한 결과 : 0.7348856209150327
