# %%
while True:
    user_id = input("아이디 입력 (영문자+숫자, 4~10자리): ")

        # 아이디 검사
    if not re.fullmatch(r'[A-Za-z0-9]{4,10}', user_id):
        print("아이디는 영문자와 숫자로만 구성된 4~10자리여야 합니다.")
    else:
        break

while True:
    phone = input("휴대폰 번호 입력 (예: 010-1234-5678): ")

    # 휴대폰 번호 검사
    if not re.fullmatch(r'010-\d{4}-\d{4}', phone):
        print("휴대폰 번호는 010-1234-5678 형식이어야 합니다.")
    else:
        break

while True:
    email = input("이메일 주소 입력 (예: 아이디@hanmail.net): ")

    # 이메일 검사
    if not re.fullmatch(r'[A-Za-z0-9]{4,10}@hanmail\.net', email):
        print("이메일은 아이디@hanmail.net 형식이어야 한다.")

    else:
        break

print(f'아이디 : {user_id}]\n휴대폰 번호 : {phone}\n이메일 : {email}')
# Out:
# 아이디 입력 (영문자+숫자, 4~10자리):  acd
# 아이디는 영문자와 숫자로만 구성된 4~10자리여야 합니다.
# 아이디 입력 (영문자+숫자, 4~10자리):  abcd4
# 휴대폰 번호 입력 (예: 010-1234-5678):  010-145
# 휴대폰 번호는 010-1234-5678 형식이어야 합니다.
# 휴대폰 번호 입력 (예: 010-1234-5678):  010-1234-1234
# 이메일 주소 입력 (예: 아이디@hanmail.net):  iimerty35@naver.com
# 이메일은 아이디@hanmail.net 형식이어야 한다.
# 이메일 주소 입력 (예: 아이디@hanmail.net):  iimerty35@hanmail.net
# 아이디 : abcd4]
# 휴대폰 번호 : 010-1234-1234
# 이메일 : iimerty35@hanmail.net
